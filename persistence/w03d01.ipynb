# %% [markdown]
# **Databases**
# - Tutorials
#     - https://www.guru99.com/dbms-tutorial.html
#     - http://www.mysqltutorial.org/
#     - https://esb-dev.github.io/dbs.html
#     - https://dev.mysql.com/doc/refman/8.0/en/
# - This week
#     - Docker
#     - Relational databases
#     - SQL
#     - JDBC
#     - Transactions
#     - JPA/Hibernate
#     - NoSQL
#     - REST

# %% [markdown]
# email@saschalippert.de
#
# **Docker**
# - https://www.youtube.com/watch?v=066-9yw8-7c
# - https://www.youtube.com/watch?v=YFl2mCHdv24

# %% [markdown]
# **Mysql Installation**
#
# 1. https://dev.mysql.com/downloads/mysql/
# 2. download mysql archive
# 3. unzip archive
# 4. create data dir in unzipped archive
# 5. open console
# 6. cd to unzipped bin dir
# 7. in bin dir run: mysqld --console --initialize-insecure
# 8. to start the mysql server run from console: mysqld --console
# 9. to start the mysql client run from console: mysql -u root

# %% [markdown]
# **Mysql UI**
# - https://www.mysql.com/products/workbench/
# - https://dbeaver.io/

# %% [markdown]
# **File based storage**
# - Shop example (articles, customers, orders, etc)
#     - One file per data category
#     - Discuss advantages
#         - Easy to learn and implement
#         - No additional software/lib required
#         - No connection overhead -> fast
#         - Human readable (depending on file format)
#         - Easy to duplicate
#     - Discuss disadvantages
#         - No multiuser support
#         - No transaction support
#         - No standardized structure
#         - Gets more complicated with size
#         - Queriying and navigating data must be implemented
#         - Redundant data
#         - Hard coupling between pysical data layer and application
#
# **Relational database**
# - What does a DMBS do?
#     - Definition
#     - Manipulation
#     - Querying
#     - Control
#     - https://www.guru99.com/what-is-dbms.html#2
# - ANSI/SPARC Architecture
#     - External level (views for each user)
#     - Conceptual level (logical database schema)
#     - Internal level (DBMS internal database model)
#     - Physical level (data storage)
#     - https://www.w3schools.in/dbms/database-architecture/
# - Distributed database
#     - One machine (app + db on one machine)
#     - Two machines (app + db on two machines)
#     - Mulitple apps to one db
#     - Mulitple apps to multiple dbs
# - Relational model
#     - Relation/Table
#     - Attribute name + Data type = Attribute/Column header
#     - Relational schema/Table header
#     - Tuple/Row
#     - Value/Cell
#     - Non key values
#     - Primary & composite key
#     - Association
#     - Foreign key
#     - Multiplicity
#     - N-ary association
#         - Employee, Project, Skill, Works in using
#     - Referential integrity
#     - Entity-Relationship model (ER model)
#     - Normalization
#         - Pros
#             - Reduce redundancy to prevent inconsistencies
#             - Easier usage/understanding
#         - Cons
#             - Performance loss
#         - 1NF: Single value per cell (atomic)
#             - Makes querying easier
#         - 2NF: 1NF + All non key values functionally dependant on key values
#             - Reduce redundancy, separation by functionality, easier understanding
#         - 3NF: 2NF + No transitive dependencies from non key values to key values
#             - Reduce redundancy, separation by functionality, easier understanding
#         - https://www.guru99.com/database-normalization.html
#         - https://de.wikipedia.org/wiki/Normalisierung_(Datenbank)
#     - Views
#     - https://www.vertabelo.com/blog/inheritance-in-a-relational-database/

# %% [markdown]
# **SQL**
# - SQL: DDL, DML, DQL, DCL
# - DDL
#     - Show databases
#     - Create/drop database
#     - Datatypes
#         - http://www.mysqltutorial.org/mysql-data-types.aspx
#     - Create/truncate/drop table
#     - Constraints (primary key, foreign key, unique)
#     - Not null
#     - Default value
#     - Auto increment, Select max id, Sequences (not supported by mysql), UUIDs
#     - Alter table
#         - Rename table
#         - Add column
#         - Remove column
#         - Modify column (data type, name, not null, default)
#         - Modify constraints
# - DML
#     - Insert
#     - Update
#     - Delete
# - Exercise DDL & DML
# - DQL
#     - Use
#     - Selection (distinct)
#     - Sorting
#     - Projection
#     - Filtering (null, like, in)
#     - Aliases
#     - Union
#     - Intersection (not supported by mysql)
#     - Cartesian product
#     - Inner join
#     - Equi join
#     - Natural join
#     - Outer join
#     - https://www.w3schools.com/sql/sql_join.asp
#     - Grouping, aggregation, having
#     - Subquery (comparison, in, exists)
# - Exercise DQL
