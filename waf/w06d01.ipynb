# %% [markdown]
# **Html**
#
# - potential topics
#     - logging config
#     - input validation
#     - jsf (???)
#     - servlets (???)
#     - spring boot https (???)
#
# - VSCode
# 	- https://code.visualstudio.com/
# 	- Extensions
# 		- HTML CSS Support
# 		- HTML Preview
# 		- W3C Validation
#
# - What is a webpage?
# 	- Static, Dynamic
# 	- Text, Images, Videos, etc
# 	- Basic building blocks of the web
# 		- HTML
# 		- CSS
# 		- JS
#
# - What is HTML?
# 	- Skeleton/structure of webpages
# 	- Elements defined by tags
# 	- Rendered in the browser
# 	- Basic HTML
# 		- DOCTYPE
# 		- <head>
# 			- <title>
# 			- <meta charset="UTF-8">
# 			- <meta name="viewport" content="width=device-width, initial-scale=1">
# 				- https://www.w3schools.com/css/css_rwd_viewport.asp
# 		- <body>
# 	- Text elements
# 		- Self enclosing elements
# 		- Block elements
# 			- <p>
# 			- <div>
# 			- Lists
# 				- <ul>
# 					- <li>
# 				- <ol>
# 					- <li>
# 				- <dl>
# 					- <dt>
# 					- <dd>
# 			- <h1> to <h6>
# 			- <blockquote>
# 			- <table>
# 				- <tr>
# 					- <th>
# 					- <td>
# 				- <thead>
# 				- <tbody>
# 		- Inline elements
# 			- <a>
# 			- <em>
# 			- <strong>
# 			- <span>
# 			- <br>
# 			- <img>
# 		- Semantic elements
# 			- https://www.w3schools.com/html/html5_semantic_elements.asp
# 	- https://developer.mozilla.org/en-US/docs/Web/HTML/Element
# 	- Attributes
# 		- id
# 		- class
# 		- src
# 		- alt
# 		- href
# 		- width
# 		- height
# 		- ... (read element documentation)
# 	- Forms
# 		- Inputs
# 			- text
# 			- checkbox
# 			- radio
# 			- dropdown
# 			- textarea
# 		- Attributes
# 			- action
# 			- method
# 		- https://developer.mozilla.org/en-US/docs/Web/HTML/Element/form
# 	- DOM
# 		- Tree model
# 		- Show debug mode
# 		- Can be manipulated programmatically
# 	- https://validator.w3.org/
#
# - exercise
# 	- build a post form that contains all inputs from above
# 	- build a spring controller to process inputs
# 	- the controller should return a html website that contains a table with the user input
# 	- validate html and remove all errors and warnings
#
# - What is CSS?
# 	- Clothing/style of webpages
# 	- Apply styles
# 		- color
# 		- width
# 		- height
# 		- text-align
# 		- etc
# 	- Style usage
# 		- Inline
# 		- Style
# 		- Link
# 	- Selectors
# 		- type
# 		- .class
# 		- #id
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/Pseudo-classes
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/Attribute_selectors
# 		- Groups
# 		⁻ Multiple classes
# 			- additive
# 			- specific
# 			- hierarchy
# 	- Imports
# 	- Overriding
# 		- Types
# 		- Classes
# 		- Ids
# 		- Style attribute
# 		- !important
# 	- Box model
# 		- width
# 		- height
# 		- padding
# 		. border
# 		- margin
# 		- https://www.w3schools.com/css/css_boxmodel.asp
# 	- Display
# 		- inline (like <span>)
# 		- block (like <p>)
# 		- inline-block (like <span> with width and height)
# 		- none
# 		- ... (read display documentation)
# 		- https://www.w3schools.com/cssref/playit.asp?filename=playcss_display
# 	- Units
# 		- https://www.w3schools.com/cssref/css_units.asp
# 	- Typography
# 		- Alignment
# 		- Font size
# 		- Color
# 		- Line height
# 		- Text decoration
# 	- Fonts
# 		- font-family
# 		- Weight
# 			- https://www.w3schools.com/cssref/pr_font_weight.asp
# 		- https://web.mit.edu/jmorzins/www/fonts.html
# 		- External
# 			- Own hosted
# 			- https://fonts.google.com/
# 	- http://jigsaw.w3.org/css-validator/
# 	- Other
# 		- Z-Index
# 		- border-radius
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/background-image
# 		- https://css-tricks.com/
#
# - exercise
# 	- style your survey and result page
# 	- validate css and remove all errors and warnings
#
# - Flexbox
# 	- Layout model
# 	- Responsive Web Design
# 	- Flow of content
# 	- Flex container
# 	- Flex items
# 	- One dimensional
# 		- Main direction
# 			- Items are arranged according to the main direction
# 			- Items do not stretch, but can shrink
# 		- Cross direction
# 			- Items stretch to fill the cross direction
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Flexible_Box_Layout/Basic_Concepts_of_Flexbox#The_two_axes_of_flexbox
# 	- flex-direction
# 		- row
# 		- row-reverse
# 		- column
# 		- column-reverse
#     - flex-wrap
# 	- Ordering
# 		- Moving items in the HTML
# 		- Flex direction
# 		- Style order
# 	- align-items (cross axis)
# 		- stretch
# 		- flex-start
# 		- flex-end
# 		- center
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/align-items
# 	- justify-content (main axis)
# 		- flex-start
# 		- flex-end
# 		- center
# 		- space-around
# 		- space-between
# 		- space-evenly
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/justify-content
# 	- Show example pages
# 		- https://www.w3schools.com/css/css3_flexbox.asp
# 	- https://developer.mozilla.org/en-US/docs/Learn/CSS/CSS_layout/Flexbox
#
# - exercise
# 	- build and style an image gallery
# 	- validate html & css and remove all errors and warnings
#
# - Grid
# 	- Layout model
# 	- Responsive Web Design
# 	- Layout of content
# 	- Works well with Flexbox for content flow
# 	- Two dimensional
# 		- grid-template-columns
# 			- https://developer.mozilla.org/de/docs/Web/CSS/grid-template-columns
# 		- grid-template-rows
# 			- https://developer.mozilla.org/de/docs/Web/CSS/grid-template-rows
# 		- grid-gap
# 		- Explicit vs implicit grid
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Grid_Layout/Basic_Concepts_of_Grid_Layout#Grid_Tracks
# 	- grid-template-area
# 		- https://developer.mozilla.org/de/docs/Web/CSS/grid-template-areas
# 		- grid-area (shothand for grid-row-start, grid-column-start, grid-row-end and grid-column-end)
# 	- 1fr unit
# 	- grid-template-rows: repeat(6, 1fr)
# 	- grid-auto-rows: minmax(50px, auto)
# 	- grid-auto-columns
# 	- Nested grids
# 	- https://cssgrid-generator.netlify.com/
#
# - exercise
# 	- build and style a classic blog website
# 	- link multiple articles in your nav
# 	- adapt and link your gallery aswell
# 	- validate html & css and remove all errors and warnings
#
# - Responsive Web Design
# 	- Multiple devices, diffrent resolutions
# 	- Start on smallest screen
# 	- Usually for small, medium and big screens
# 	- Media queries
# 		- min-width
# 		- max-width
# 		- Can override css styles
# 		- Ranges can be used for multiple screen resolutions
# 		- https://developer.mozilla.org/en-US/docs/Web/CSS/Media_Queries/Using_media_queries
# 	- https://developer.mozilla.org/en-US/docs/Tools/Responsive_Design_Mode
# 	- https://developers.google.com/web/tools/chrome-devtools/device-mode/
# 	- Design systems
# 		- https://www.forumone.com/ideas/what-is-design-system/
